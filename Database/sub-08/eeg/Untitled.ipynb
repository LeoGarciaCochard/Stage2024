# %%
# %matplotlib qt

# %%
import mne

input_fname = './sub-08_task-work_run-01_eeg.edf'

# Lecture du fichier EDF
raw = mne.io.read_raw_edf(input_fname, preload=True, verbose=True)

# Conversion des annotations en événements
events, event_id = mne.events_from_annotations(raw)

# Affichage du signal brut (vous verrez les annotations en surbrillance)
raw.plot()

# Affichage des événements détectés
mne.viz.plot_events(events, event_id=event_id)

# Possibilité de superposer ces événements dans la fenêtre Raw :
raw.plot(events=events, event_id=event_id)
# Out:
# Extracting EDF parameters from C:\Users\milio\PycharmProjects\Stage2024\Database\sub-08\eeg\sub-08_task-work_run-01_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 40959  =      0.000 ...    79.998 secs...
# Used Annotations descriptions: ['OVTK_StimulationId_Label_01', 'OVTK_StimulationId_Label_05', 'OVTK_StimulationId_Label_06', '[Total time]+80.000']
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1329x840 with 4 Axes>
# Traceback (most recent call last):
#   File "C:\Users\milio\anaconda3\Lib\site-packages\matplotlib\cbook\__init__.py", line 304, in process
#     func(*args, **kwargs)
#   File "C:\Users\milio\anaconda3\Lib\site-packages\mne\viz\_mpl_figure.py", line 868, in _pick
#     self._create_ch_context_fig(ind)
#   File "C:\Users\milio\anaconda3\Lib\site-packages\mne\viz\_mpl_figure.py", line 871, in _create_ch_context_fig
#     fig = super()._create_ch_context_fig(idx)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\milio\anaconda3\Lib\site-packages\mne\viz\_figure.py", line 472, in _create_ch_context_fig
#     fig = self._create_ch_location_fig(pick)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\milio\anaconda3\Lib\site-packages\mne\viz\_figure.py", line 494, in _create_ch_location_fig
#     _ = plot_sensors(
#         ^^^^^^^^^^^^^
#   File "<decorator-gen-105>", line 12, in plot_sensors
#   File "C:\Users\milio\anaconda3\Lib\site-packages\mne\viz\utils.py", line 1066, in plot_sensors
#     raise RuntimeError("No valid channel positions found")
# RuntimeError: No valid channel positions found
